# %%
import pandas as pd

car_sales_df = pd.read_csv('car-sales.csv')
car_sales_df
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
# series = 1-dimensional
# dataframe = 2-dimensional

# %%
series = pd.Series([300, 100003, 328793489])
series
# Out:
# 0          300
# 1       100003
# 2    328793489
# dtype: int64

# %%
makes = pd.Series(['BMW','Toyota','Honda'])
makes
# Out:
# 0       BMW
# 1    Toyota
# 2     Honda
# dtype: object

# %%
colours = pd.Series(['Red', 'Blue','White'])
colours
# Out:
# 0      Red
# 1     Blue
# 2    White
# dtype: object

# %%
df = pd.DataFrame({'Car Makes':makes, 'Colours': colours})

# %%
df
# Out:
#   Car Makes Colours
# 0       BMW     Red
# 1    Toyota    Blue
# 2     Honda   White

# %%
# we usually go to import data rather than creating series and dataframe

# %%
import pandas as pd

car_sales_df = pd.read_csv('car-sales.csv')
car_sales_df
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
# Exporting a dataframe
car_sales_df.to_csv('exported_car_sales.csv')
# Then you can use read_csv again to read the new file

# you can also export as Excel
# car_sales_df.to_excel()

# %% [markdown]
# ## Describe data

# %%
car_sales_df.dtypes
# Out:
# Make             object
# Colour           object
# Odometer (KM)     int64
# Doors             int64
# Price            object
# dtype: object

# %%
car_sales_df.columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
car_sales_df.shape
# Out:
# (10, 5)

# %%
car_sales_df.index
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %%
car_sales_df.Price
# Out:
# 0     $4,000.00
# 1     $5,000.00
# 2     $7,000.00
# 3    $22,000.00
# 4     $3,500.00
# 5     $4,500.00
# 6     $7,500.00
# 7     $7,000.00
# 8     $6,250.00
# 9     $9,700.00
# Name: Price, dtype: object

# %%
car_sales_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Make           10 non-null     object
#  1   Colour         10 non-null     object
#  2   Odometer (KM)  10 non-null     int64
#  3   Doors          10 non-null     int64
#  4   Price          10 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 528.0+ bytes

# %%
car_sales_df.describe()
# describe only work on numerical columns
# Out:
#        Odometer (KM)      Doors
# count      10.000000  10.000000
# mean    78601.400000   4.000000
# std     61983.471735   0.471405
# min     11179.000000   3.000000
# 25%     35836.250000   4.000000
# 50%     57369.000000   4.000000
# 75%     96384.500000   4.000000
# max    213095.000000   5.000000

# %%
car_sales_df.mean(numeric_only=True)
# Out:
# Odometer (KM)    78601.4
# Doors                4.0
# dtype: float64

# %%
car_sales_df.sum()
# Out:
# Make             ToyotaHondaToyotaBMWNissanToyotaHondaHondaToyo...
# Colour               WhiteRedBlueBlackWhiteGreenBlueBlueWhiteWhite
# Odometer (KM)                                               786014
# Doors                                                           40
# Price            $4,000.00$5,000.00$7,000.00$22,000.00$3,500.00...
# dtype: object

# %%
car_sales_df.sum(numeric_only=True)
# Out:
# Odometer (KM)    786014
# Doors                40
# dtype: int64

# %%
car_sales_df.Doors.sum()
# Out:
# 40

# %%
len(car_sales_df)
# Out:
# 10

# %%
car_sales_df.size
# Out:
# 50

# %%
car_sales_df.shape
# Out:
# (10, 5)

# %% [markdown]
# ## Viewing and selecting data
#
# #### access by index using loc (refer to index ) & iloc (refer to position)
#
# #### access by columns using columns

# %%
car_sales_df.head(10)
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales_df.head()
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00

# %%
car_sales_df.tail()
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 5  Toyota  Green          99213      4  $4,500.00
# 6   Honda   Blue          45698      4  $7,500.00
# 7   Honda   Blue          54738      4  $7,000.00
# 8  Toyota  White          60000      4  $6,250.00
# 9  Nissan  White          31600      4  $9,700.00

# %%
# .iloc & .loc
animals = pd.Series(['cat','dog','bird','panda','snake'])

# %%
animals
# Out:
# 0      cat
# 1      dog
# 2     bird
# 3    panda
# 4    snake
# dtype: object

# %%
# using a custom index
animals = pd.Series(['cat','dog','bird','panda','snake'],
                  index=[1,2,3,4,3])

# %%
animals
# Out:
# 1      cat
# 2      dog
# 3     bird
# 4    panda
# 3    snake
# dtype: object

# %%
# Use .loc to select the row at index 3 of the DataFrame
# 3 inside the loc is the index value
animals.loc[3]
# Out:
# 3     bird
# 3    snake
# dtype: object

# %%
# 3 inside the iloc is the integer index of the rows (refer to the position)
animals.iloc[3]
# Out:
# 'panda'

# %%
car_sales_df.loc[3]
# Out:
# Make                    BMW
# Colour                Black
# Odometer (KM)         11179
# Doors                     5
# Price            $22,000.00
# Name: 3, dtype: object

# %%
# car_sales_df.iloc[3] will get the same

# %%
animals.iloc[:3] 
# doesn't include 3 for iloc
# Out:
# 1     cat
# 2     dog
# 3    bird
# dtype: object

# %%
car_sales_df.loc[:3]
# include 3 for loc
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00

# %%
car_sales_df['Colour']
# Out:
# 0    White
# 1      Red
# 2     Blue
# 3    Black
# 4    White
# 5    Green
# 6     Blue
# 7     Blue
# 8    White
# 9    White
# Name: Colour, dtype: object

# %%
car_sales_df.Colour
# Out:
# 0    White
# 1      Red
# 2     Blue
# 3    Black
# 4    White
# 5    Green
# 6     Blue
# 7     Blue
# 8    White
# 9    White
# Name: Colour, dtype: object

# %%
car_sales_df[car_sales_df['Make'] == 'Toyota']
# boolean indexing
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 2  Toyota   Blue          32549      3  $7,000.00
# 5  Toyota  Green          99213      4  $4,500.00
# 8  Toyota  White          60000      4  $6,250.00

# %%
i = car_sales_df.columns[:1]
print(i)
print(i.values)
car_sales_df[i]
# Out:
# Index(['Make'], dtype='object')
# ['Make']
#      Make
# 0  Toyota
# 1   Honda
# 2  Toyota
# 3     BMW
# 4  Nissan
# 5  Toyota
# 6   Honda
# 7   Honda
# 8  Toyota
# 9  Nissan

# %%
car_sales_df
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales_df[car_sales_df['Odometer (KM)'] > 100000]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 4  Nissan  White         213095      4  $3,500.00

# %%
car_sales_df.index[:3]
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
car_sales_df_index = car_sales_df.index[:3]

car_sales_df_index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
car_sales_df_index.values
# Out:
# array([0, 1, 2])

# %%
# Need to review
# crosstab is great for comparing two columns
pd.crosstab(car_sales_df['Make'], car_sales_df['Doors'])
# Out:
# Doors   3  4  5
# Make
# BMW     0  0  1
# Honda   0  3  0
# Nissan  0  2  0
# Toyota  1  3  0

# %%
# grouby
car_sales_df.groupby(['Make']).mean()
# Out:
#         Odometer (KM)  Doors
# Make
# BMW      11179.000000   5.00
# Honda    62778.333333   4.00
# Nissan  122347.500000   4.00
# Toyota   85451.250000   3.75

# %%
car_sales_df.groupby(['Make'])

# %%
car_sales_df['Odometer (KM)'].plot()
# Out:
# <AxesSubplot:>

# %%
car_sales_df['Odometer (KM)'].hist()
# Out:
# <AxesSubplot:>

# %%
# 
car_sales_df['Price'] = car_sales_df['Price'].astype(int)
car_sales_df
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   400000
# 1   Honda    Red          87899      4   500000
# 2  Toyota   Blue          32549      3   700000
# 3     BMW  Black          11179      5  2200000
# 4  Nissan  White         213095      4   350000
# 5  Toyota  Green          99213      4   450000
# 6   Honda   Blue          45698      4   750000
# 7   Honda   Blue          54738      4   700000
# 8  Toyota  White          60000      4   625000
# 9  Nissan  White          31600      4   970000

# %%
car_sales_df['Make'].str.lower()
# Out:
# 0    toyota
# 1     honda
# 2    toyota
# 3       bmw
# 4    nissan
# 5    toyota
# 6     honda
# 7     honda
# 8    toyota
# 9    nissan
# Name: Make, dtype: object

# %%
car_sales_df
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   400000
# 1   Honda    Red          87899      4   500000
# 2  Toyota   Blue          32549      3   700000
# 3     BMW  Black          11179      5  2200000
# 4  Nissan  White         213095      4   350000
# 5  Toyota  Green          99213      4   450000
# 6   Honda   Blue          45698      4   750000
# 7   Honda   Blue          54738      4   700000
# 8  Toyota  White          60000      4   625000
# 9  Nissan  White          31600      4   970000

# %%
car_sales_df['Make'] = car_sales_df['Make'].str.lower()

# %%
car_sales_df
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  toyota  White         150043      4   400000
# 1   honda    Red          87899      4   500000
# 2  toyota   Blue          32549      3   700000
# 3     bmw  Black          11179      5  2200000
# 4  nissan  White         213095      4   350000
# 5  toyota  Green          99213      4   450000
# 6   honda   Blue          45698      4   750000
# 7   honda   Blue          54738      4   700000
# 8  toyota  White          60000      4   625000
# 9  nissan  White          31600      4   970000

# %%
car_sales_missing_data_df = pd.read_csv('car-sales-missing-data.csv')
car_sales_missing_data_df
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
mean = car_sales_missing_data_df['Odometer'].mean()

# %%
# car_sales_missing_data_df['Odometer'] = car_sales_missing_data_df['Odometer'].fillna(mean)
car_sales_missing_data_df['Odometer'].fillna(mean, inplace=True)

# %%
car_sales_missing_data_df
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500
# 6   Honda    NaN   92302.666667    4.0   $7,500
# 7   Honda   Blue   92302.666667    4.0      NaN
# 8  Toyota  White   60000.000000    NaN      NaN
# 9     NaN  White   31600.000000    4.0   $9,700

# %%
car_sales_missing_data_df.dropna(inplace=True)

# %%
car_sales_missing_data_df
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500

# %%
car_sales_missing_data_df.to_csv('car_sales_missing_dropped')

# %%
# column from series
car_sales_missing_data_df = pd.read_csv('car-sales-missing-data.csv')
car_sales_missing_data_df
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
# column from series
series = pd.Series([5,5,5,5,5])

car_sales_missing_data_df['Seats'] = series
car_sales_missing_data_df
# Out:
#      Make Colour  Odometer  Doors    Price  Seats
# 0  Toyota  White  150043.0    4.0   $4,000    5.0
# 1   Honda    Red   87899.0    4.0   $5,000    5.0
# 2  Toyota   Blue       NaN    3.0   $7,000    5.0
# 3     BMW  Black   11179.0    5.0  $22,000    5.0
# 4  Nissan  White  213095.0    4.0   $3,500    5.0
# 5  Toyota  Green       NaN    4.0   $4,500    NaN
# 6   Honda    NaN       NaN    4.0   $7,500    NaN
# 7   Honda   Blue       NaN    4.0      NaN    NaN
# 8  Toyota  White   60000.0    NaN      NaN    NaN
# 9     NaN  White   31600.0    4.0   $9,700    NaN

# %%
car_sales_missing_data_df['Seats'].fillna(5, inplace=True)

# %%
car_sales_missing_data_df
# Out:
#      Make Colour  Odometer  Doors    Price  Seats
# 0  Toyota  White  150043.0    4.0   $4,000    5.0
# 1   Honda    Red   87899.0    4.0   $5,000    5.0
# 2  Toyota   Blue       NaN    3.0   $7,000    5.0
# 3     BMW  Black   11179.0    5.0  $22,000    5.0
# 4  Nissan  White  213095.0    4.0   $3,500    5.0
# 5  Toyota  Green       NaN    4.0   $4,500    5.0
# 6   Honda    NaN       NaN    4.0   $7,500    5.0
# 7   Honda   Blue       NaN    4.0      NaN    5.0
# 8  Toyota  White   60000.0    NaN      NaN    5.0
# 9     NaN  White   31600.0    4.0   $9,700    5.0

# %%
# column from python list
# it has to be the same length of the rows
fuel_economy = [7.5,9.2,5.0,9.6,8.7,4.7,8.6,3.5,6.7,6.4]
car_sales_missing_data_df['Fuel Per 100KM'] = fuel_economy
car_sales_missing_data_df
# Out:
#      Make Colour  Odometer  Doors    Price  Seats  Fuel Per 100KM
# 0  Toyota  White  150043.0    4.0   $4,000    5.0             7.5
# 1   Honda    Red   87899.0    4.0   $5,000    5.0             9.2
# 2  Toyota   Blue       NaN    3.0   $7,000    5.0             5.0
# 3     BMW  Black   11179.0    5.0  $22,000    5.0             9.6
# 4  Nissan  White  213095.0    4.0   $3,500    5.0             8.7
# 5  Toyota  Green       NaN    4.0   $4,500    5.0             4.7
# 6   Honda    NaN       NaN    4.0   $7,500    5.0             8.6
# 7   Honda   Blue       NaN    4.0      NaN    5.0             3.5
# 8  Toyota  White   60000.0    NaN      NaN    5.0             6.7
# 9     NaN  White   31600.0    4.0   $9,700    5.0             6.4

# %%
# column from existing column
car_sales_missing_data_df['Total fuel used (L)'] = car_sales_missing_data_df['Odometer']/100*car_sales_missing_data_df['Fuel Per 100KM']

# %%
car_sales_missing_data_df
# Out:
#      Make Colour  Odometer  Doors    Price  Seats  Fuel Per 100KM  \
# 0  Toyota  White  150043.0    4.0   $4,000    5.0             7.5
# 1   Honda    Red   87899.0    4.0   $5,000    5.0             9.2
# 2  Toyota   Blue       NaN    3.0   $7,000    5.0             5.0
# 3     BMW  Black   11179.0    5.0  $22,000    5.0             9.6
# 4  Nissan  White  213095.0    4.0   $3,500    5.0             8.7
# 5  Toyota  Green       NaN    4.0   $4,500    5.0             4.7
# 6   Honda    NaN       NaN    4.0   $7,500    5.0             8.6
# 7   Honda   Blue       NaN    4.0      NaN    5.0             3.5
# 8  Toyota  White   60000.0    NaN      NaN    5.0             6.7
# 9     NaN  White   31600.0    4.0   $9,700    5.0             6.4
#
#    Total fuel used  Total fuel used (L)
# 0        11253.225            11253.225
# 1         8086.708             8086.708
# 2              NaN                  NaN
# 3         1073.184             1073.184
# ...

# %%
# create a column from a single value
car_sales_missing_data_df['Number of wheel'] = 4

# %%
car_sales_missing_data_df
# Out:
#      Make Colour  Odometer  Doors    Price  Seats  Fuel Per 100KM  \
# 0  Toyota  White  150043.0    4.0   $4,000    5.0             7.5
# 1   Honda    Red   87899.0    4.0   $5,000    5.0             9.2
# 2  Toyota   Blue       NaN    3.0   $7,000    5.0             5.0
# 3     BMW  Black   11179.0    5.0  $22,000    5.0             9.6
# 4  Nissan  White  213095.0    4.0   $3,500    5.0             8.7
# 5  Toyota  Green       NaN    4.0   $4,500    5.0             4.7
# 6   Honda    NaN       NaN    4.0   $7,500    5.0             8.6
# 7   Honda   Blue       NaN    4.0      NaN    5.0             3.5
# 8  Toyota  White   60000.0    NaN      NaN    5.0             6.7
# 9     NaN  White   31600.0    4.0   $9,700    5.0             6.4
#
#    Total fuel used  Total fuel used (L)  Nu,ber of wheel  Number of wheel
# 0        11253.225            11253.225                4                4
# 1         8086.708             8086.708                4                4
# ...

# %%
car_sales_missing_data_df.drop('Total fuel used', axis=1)
# Out:
#      Make Colour  Odometer  Doors    Price  Seats  Fuel Per 100KM  \
# 0  Toyota  White  150043.0    4.0   $4,000    5.0             7.5
# 1   Honda    Red   87899.0    4.0   $5,000    5.0             9.2
# 2  Toyota   Blue       NaN    3.0   $7,000    5.0             5.0
# 3     BMW  Black   11179.0    5.0  $22,000    5.0             9.6
# 4  Nissan  White  213095.0    4.0   $3,500    5.0             8.7
# 5  Toyota  Green       NaN    4.0   $4,500    5.0             4.7
# 6   Honda    NaN       NaN    4.0   $7,500    5.0             8.6
# 7   Honda   Blue       NaN    4.0      NaN    5.0             3.5
# 8  Toyota  White   60000.0    NaN      NaN    5.0             6.7
# 9     NaN  White   31600.0    4.0   $9,700    5.0             6.4
#
#    Total fuel used (L)  Nu,ber of wheel  Number of wheel
# 0            11253.225                4                4
# 1             8086.708                4                4
# 2                  NaN                4                4
# ...

# %%
car_sales_missing_data_df.drop('Nu,ber of wheel', axis=1)
# Out:
#      Make Colour  Odometer  Doors    Price  Seats  Fuel Per 100KM  \
# 0  Toyota  White  150043.0    4.0   $4,000    5.0             7.5
# 1   Honda    Red   87899.0    4.0   $5,000    5.0             9.2
# 2  Toyota   Blue       NaN    3.0   $7,000    5.0             5.0
# 3     BMW  Black   11179.0    5.0  $22,000    5.0             9.6
# 4  Nissan  White  213095.0    4.0   $3,500    5.0             8.7
# 5  Toyota  Green       NaN    4.0   $4,500    5.0             4.7
# 6   Honda    NaN       NaN    4.0   $7,500    5.0             8.6
# 7   Honda   Blue       NaN    4.0      NaN    5.0             3.5
# 8  Toyota  White   60000.0    NaN      NaN    5.0             6.7
# 9     NaN  White   31600.0    4.0   $9,700    5.0             6.4
#
#    Total fuel used  Total fuel used (L)  Number of wheel
# 0        11253.225            11253.225                4
# 1         8086.708             8086.708                4
# 2              NaN                  NaN                4
# ...

# %%
import pandas as pd

car_sales = pd.read_csv('car-sales.csv')
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
# shuffle all the data
car_sales_shuffled= car_sales.sample(frac=1)
car_sales_shuffled
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 9  Nissan  White          31600      4   $9,700.00
# 5  Toyota  Green          99213      4   $4,500.00
# 3     BMW  Black          11179      5  $22,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 7   Honda   Blue          54738      4   $7,000.00
# 6   Honda   Blue          45698      4   $7,500.00

# %%
# shuffle some fraction of the data
car_sales.sample(frac = 0.2)
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 5  Toyota  Green          99213      4  $4,500.00
# 7   Honda   Blue          54738      4  $7,000.00

# %%
# you can reset the indext to the original one
car_sales_shuffled.reset_index(drop=True,inplace=True)

# %%
car_sales_shuffled
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Nissan  White         213095      4   $3,500.00
# 3  Nissan  White          31600      4   $9,700.00
# 4  Toyota  Green          99213      4   $4,500.00
# 5     BMW  Black          11179      5  $22,000.00
# 6  Toyota   Blue          32549      3   $7,000.00
# 7  Toyota  White          60000      4   $6,250.00
# 8   Honda   Blue          54738      4   $7,000.00
# 9   Honda   Blue          45698      4   $7,500.00

# %%
# apply function to the dataframe columns
car_sales['Odometer (KM)'] = car_sales['Odometer (KM)'].apply(lambda x: x/1.6)
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White      93776.875      4   $4,000.00
# 1   Honda    Red      54936.875      4   $5,000.00
# 2  Toyota   Blue      20343.125      3   $7,000.00
# 3     BMW  Black       6986.875      5  $22,000.00
# 4  Nissan  White     133184.375      4   $3,500.00
# 5  Toyota  Green      62008.125      4   $4,500.00
# 6   Honda   Blue      28561.250      4   $7,500.00
# 7   Honda   Blue      34211.250      4   $7,000.00
# 8  Toyota  White      37500.000      4   $6,250.00
# 9  Nissan  White      19750.000      4   $9,700.00
